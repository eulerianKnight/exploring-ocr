# %% [markdown]
# # Pre-Processing Techniques for OCR

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt

# %%
img = cv2.imread('/teamspace/studios/this_studio/exploring-ocr/understanding-ocr/images/img-process.jpg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb);
plt.axis('off');

# %%
# Convert to gray scale image
img_gray = cv2.cvtColor(rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray, cmap='gray');
plt.axis('off');

# %% [markdown]
# ## Thresholding
#
# - Thresholding (binarization) is the simplest method of image segmentation.
# - It consists of separating an image into regions of interest and non-interest by choosing a cut-off point(called threshold)
# - The value of the new color that the pixel will have is calculated according to the cutoff point (threshold).
# - Any pixel with intensity less than or equal to the threshold becomes black. If the pixel has an intensity greater thaan the threshold, it becomes white.
# - Otsu's Method: Read here https://learnopencv.com/otsu-thresholding-with-opencv/
# - Adaptive Thresholding (Gaussian)
#     - The threshold is calculated for small regions of the image, different thresholds are obtained for small regions of the image(using the average)
#     - Gaussian: Also uses standard deviation (considering the variation in the pixels) - uses convolution.

# %% [markdown]
# ### Simple Thresholding

# %%
img = cv2.imread('/teamspace/studios/this_studio/exploring-ocr/understanding-ocr/images/page-book.jpg')
plt.imshow(img);
plt.axis('off');
